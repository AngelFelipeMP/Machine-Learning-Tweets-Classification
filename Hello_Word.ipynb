# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelFelipeMP/Machine-Learning-Tweets-Classification/blob/main/Hello_Word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world')
# Out:
# Hello world

# %%
Cell test

# %%
"3th cell"
# Out:
# '3th cell'
