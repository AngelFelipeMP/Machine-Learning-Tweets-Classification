# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
# Path for all results
PathStatisticalModels = "drive/MyDrive/Code/DETOXIS/Machine-Learning-Tweets-Classification/Statistical_Models/Results/"
PathBertModels = "drive/MyDrive/Code/DETOXIS/Machine-Learning-Tweets-Classification/Bert/Results/"

# %%
# File Names
### Statistical Models
MeTask1 = "ME_results_task1"
MeTask2 = "ME_results_task2"
NbTask1 = "NB_results_task1"
NbTask2 = "NB_results_task2"

###Bert Model
MlbTask1 = "AverageBertMutilingual_results_task1"
MlbTask2 = "AverageMultilingualBertTask2Results_CSV_"
BetoTask1 = "AverageBertSpanish_results_task1"
BetoTask2 = "AverageSpanishBertTask2Results_CSV_"

# %% [markdown]
# # Task1

# %% [markdown]
# ## Statistical models

# %% [markdown]
# ### ME

# %%
# Read Maximum Entropy model results
df_MeTask1 = pd.read_csv(PathStatisticalModels + MeTask1 + ".csv")
df_MeTask1.head()
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2  accuracy        f1    recall  precision
# 0  liblinear_ME      tfidf     (1, 1)  0.711188  0.303147  0.202090   0.688248
# 1  liblinear_ME      tfidf     (1, 2)  0.697621  0.154633  0.094851   0.878563
# 2  liblinear_ME      tfidf     (1, 3)  0.689251  0.103558  0.063501   0.650000
# 3  liblinear_ME      occur     (1, 1)  0.699355  0.465244  0.399306   0.564882
# 4  liblinear_ME      occur     (1, 2)  0.711770  0.435252  0.343394   0.605985

# %%
# rank results by f1-score
df_MeTask1 = df_MeTask1.sort_values('f1', ascending=False)
df_MeTask1.head()
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2  accuracy        f1    recall  precision
# 15        sag_ME      occur     (1, 1)  0.700222  0.467890  0.401915   0.567011
# 3   liblinear_ME      occur     (1, 1)  0.699355  0.465244  0.399306   0.564882
# 21       saga_ME      occur     (1, 1)  0.698492  0.465197  0.400175   0.562916
# 27      lbfgs_ME      occur     (1, 1)  0.699066  0.464548  0.398436   0.564657
# 9      newton_ME      occur     (1, 1)  0.699066  0.464548  0.398436   0.564657

# %% [markdown]
# ### NB

# %%
# Read Naive Bayse model results
df_NbTask1 = pd.read_csv(PathStatisticalModels + NbTask1 + ".csv")
df_NbTask1.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  accuracy        f1    recall  precision
# 0    mulNB_c      tfidf     (1, 1)  0.693293  0.170334  0.106217   0.728195
# 1    mulNB_c      tfidf     (1, 2)  0.687809  0.099490  0.060885   0.716667
# 2    mulNB_c      tfidf     (1, 3)  0.684348  0.080508  0.048703   0.550000
# 3    mulNB_c      occur     (1, 1)  0.668473  0.486837  0.482113   0.495998
# 4    mulNB_c      occur     (1, 2)  0.647978  0.523242  0.586781   0.473583

# %%
# rank results by f1-score
df_NbTask1 = df_NbTask1.sort_values('f1', ascending=False)
df_NbTask1.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  accuracy        f1    recall  precision
# 5     mulNB_c      occur     (1, 3)  0.579550  0.535522  0.728894   0.423795
# 23    comNB_c      occur     (1, 3)  0.521516  0.525603  0.800404   0.391500
# 4     mulNB_c      occur     (1, 2)  0.647978  0.523242  0.586781   0.473583
# 22    comNB_c      occur     (1, 2)  0.592833  0.521595  0.674851   0.426254
# 21    comNB_c      occur     (1, 1)  0.623427  0.516491  0.615561   0.447195

# %% [markdown]
# ## Bert Models

# %% [markdown]
# ### BETO

# %%
# Read BETO model results
df_BetoTask1 = pd.read_csv(PathBertModels + BetoTask1 + ".csv")
df_BetoTask1.head()
# Out:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2  ...    recall  precision      loss
# 0  SpanishBert     hidden     0.00001  ...  0.354750   0.721950  0.624056
# 1  SpanishBert     hidden     0.00001  ...  0.429728   0.739075  0.438842
# 2  SpanishBert     hidden     0.00001  ...  0.557383   0.664583  0.243240
# 3  SpanishBert     hidden     0.00001  ...  0.585898   0.654069  0.172412
# 4  SpanishBert     hidden     0.00001  ...  0.498089   0.713554  0.163945
#
# [5 rows x 10 columns]

# %%
df_BetoTask1 = df_BetoTask1.sort_values('f1', ascending=False)
df_BetoTask1.head()
# Out:
#       Unnamed: 0 Unnamed: 1  Unnamed: 2  ...    recall  precision      loss
# 283  SpanishBert     pooler     0.00001  ...  0.651356   0.633806  0.292655
# 306  SpanishBert     pooler     0.00001  ...  0.657827   0.618375  0.264552
# 266  SpanishBert     pooler     0.00001  ...  0.682886   0.601620  0.105680
# 473  SpanishBert     pooler     0.00005  ...  0.620312   0.648528  0.006428
# 395  SpanishBert     pooler     0.00003  ...  0.611697   0.656825  0.003672
#
# [5 rows x 10 columns]

# %% [markdown]
# ### MLB

# %%
# Read Mutilingual Berte model results
df_MlbTask1 = pd.read_csv(PathBertModels + MlbTask1 + ".csv")
df_MlbTask1.head()
# Out:
#          Unnamed: 0 Unnamed: 1  Unnamed: 2  ...    recall  precision      loss
# 0  MultilingualBert     hidden     0.00001  ...  0.152796   0.592262  0.629409
# 1  MultilingualBert     hidden     0.00001  ...  0.220721   0.669337  0.489646
# 2  MultilingualBert     hidden     0.00001  ...  0.346517   0.675908  0.394863
# 3  MultilingualBert     hidden     0.00001  ...  0.563279   0.622532  0.305304
# 4  MultilingualBert     hidden     0.00001  ...  0.547912   0.637661  0.230373
#
# [5 rows x 10 columns]

# %%
df_MlbTask1 = df_MlbTask1.sort_values('f1', ascending=False)
df_MlbTask1.head()
# Out:
#            Unnamed: 0 Unnamed: 1  Unnamed: 2  ...    recall  precision      loss
# 370  MultilingualBert     pooler     0.00003  ...  0.684242   0.559408  0.070355
# 207  MultilingualBert     hidden     0.00005  ...  0.616749   0.575945  0.154952
# 208  MultilingualBert     hidden     0.00005  ...  0.620233   0.571293  0.079418
# 155  MultilingualBert     hidden     0.00003  ...  0.577770   0.608307  0.020192
# 347  MultilingualBert     pooler     0.00003  ...  0.671462   0.531854  0.111094
#
# [5 rows x 10 columns]

# %% [markdown]
# # Task2

# %% [markdown]
# ## Statistical models

# %% [markdown]
# ### ME

# %%
# Read Maximum Entropy model results
df_MeTask2 = pd.read_csv(PathStatisticalModels + MeTask2 + ".csv")
df_MeTask2.head()
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2  ...    recall  precision       cem
# 0  liblinear_ME      tfidf     (1, 1)  ...  0.682621   0.682621  0.707041
# 1  liblinear_ME      tfidf     (1, 2)  ...  0.680890   0.680890  0.697224
# 2  liblinear_ME      tfidf     (1, 3)  ...  0.679736   0.679736  0.692280
# 3  liblinear_ME      occur     (1, 1)  ...  0.652593   0.652593  0.683130
# 4  liblinear_ME      occur     (1, 2)  ...  0.672225   0.672225  0.701811
#
# [5 rows x 9 columns]

# %%
# rank results by f1-score
df_MeTask2 = df_MeTask2.sort_values('cem', ascending=False)
df_MeTask2.head()
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2  ...    recall  precision       cem
# 5   liblinear_ME      occur     (1, 3)  ...  0.678005   0.678005  0.707983
# 0   liblinear_ME      tfidf     (1, 1)  ...  0.682621   0.682621  0.707041
# 12        sag_ME      tfidf     (1, 1)  ...  0.682614   0.682614  0.706660
# 24      lbfgs_ME      tfidf     (1, 1)  ...  0.682614   0.682614  0.706660
# 6      newton_ME      tfidf     (1, 1)  ...  0.682614   0.682614  0.706660
#
# [5 rows x 9 columns]

# %% [markdown]
# ### NB

# %%
# Read Naive Bayse model results
df_NbTask2 = pd.read_csv(PathStatisticalModels + NbTask2 + ".csv")
df_NbTask2.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  ...    recall  precision       cem
# 0    mulNB_c      tfidf     (1, 1)  ...  0.674255   0.674255  0.680835
# 1    mulNB_c      tfidf     (1, 2)  ...  0.676854   0.676854  0.688164
# 2    mulNB_c      tfidf     (1, 3)  ...  0.676567   0.676567  0.688062
# 3    mulNB_c      occur     (1, 1)  ...  0.615069   0.615069  0.638369
# 4    mulNB_c      occur     (1, 2)  ...  0.606120   0.606120  0.647322
#
# [5 rows x 9 columns]

# %%
# rank results by f1-score
df_NbTask2 = df_NbTask2.sort_values('cem', ascending=False)
df_NbTask2.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  ...    recall  precision       cem
# 1    mulNB_c      tfidf     (1, 2)  ...  0.676854   0.676854  0.688164
# 2    mulNB_c      tfidf     (1, 3)  ...  0.676567   0.676567  0.688062
# 0    mulNB_c      tfidf     (1, 1)  ...  0.674255   0.674255  0.680835
# 4    mulNB_c      occur     (1, 2)  ...  0.606120   0.606120  0.647322
# 3    mulNB_c      occur     (1, 1)  ...  0.615069   0.615069  0.638369
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Bert Models

# %% [markdown]
# ### BETO

# %%
# Read BETO model results
df_BetoTask2 = pd.read_csv(PathBertModels + BetoTask2 + ".csv")
df_BetoTask2.head()
# Out:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2  ...  precision       cem  loss
# 0  SpanishBert     hidden     0.00001  ...   0.331216  0.722565   NaN
# 1  SpanishBert     hidden     0.00001  ...   0.424997  0.769625   NaN
# 2  SpanishBert     hidden     0.00001  ...   0.461104  0.774677   NaN
# 3  SpanishBert     hidden     0.00001  ...   0.456023  0.764872   NaN
# 4  SpanishBert     hidden     0.00001  ...   0.459225  0.773905   NaN
#
# [5 rows x 12 columns]

# %%
df_BetoTask2 = df_BetoTask2.sort_values('cem', ascending=False)
df_BetoTask2.head()
# Out:
#       Unnamed: 0 Unnamed: 1  Unnamed: 2  ...  precision       cem      loss
# 23   SpanishBert     hidden     0.00001  ...   0.446873  0.776860       NaN
# 2    SpanishBert     hidden     0.00001  ...   0.461104  0.774677       NaN
# 125  SpanishBert     hidden     0.00003  ...   0.435515  0.774593       NaN
# 144  SpanishBert     hidden     0.00003  ...   0.446093  0.774551  0.541801
# 4    SpanishBert     hidden     0.00001  ...   0.459225  0.773905       NaN
#
# [5 rows x 12 columns]

# %% [markdown]
# ### MLB

# %%
# Read Mutilingual Berte model results
df_MlbTask2 = pd.read_csv(PathBertModels + MlbTask2 + ".csv")
df_MlbTask2.head()
# Out:
#          Unnamed: 0 Unnamed: 1  Unnamed: 2  ...  precision       cem  loss
# 0  MultilingualBert     hidden     0.00001  ...   0.298946  0.705382   NaN
# 1  MultilingualBert     hidden     0.00001  ...   0.378951  0.748721   NaN
# 2  MultilingualBert     hidden     0.00001  ...   0.431972  0.753842   NaN
# 3  MultilingualBert     hidden     0.00001  ...   0.410459  0.749284   NaN
# 4  MultilingualBert     hidden     0.00001  ...   0.401839  0.747019   NaN
#
# [5 rows x 12 columns]

# %%
df_MlbTask2 = df_MlbTask2.sort_values('cem', ascending=False)
df_MlbTask2.head()
# Out:
#            Unnamed: 0 Unnamed: 1  Unnamed: 2  ...  precision       cem  loss
# 271  MultilingualBert     pooler     0.00001  ...   0.448257  0.759914   NaN
# 33   MultilingualBert     hidden     0.00001  ...   0.434420  0.758755   NaN
# 103  MultilingualBert     hidden     0.00003  ...   0.405366  0.758065   NaN
# 29   MultilingualBert     hidden     0.00001  ...   0.420951  0.757991   NaN
# 263  MultilingualBert     pooler     0.00001  ...   0.418198  0.757991   NaN
#
# [5 rows x 12 columns]
